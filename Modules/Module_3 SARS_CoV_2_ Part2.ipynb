# %% [markdown]
# # Módulo 3: Parte 2 de identificação da linhagem variante do SARS-CoV-2
# Bem-vindo ao módulo! Existem algumas instruções muito importantes para você seguir:
#
# 1.) Clique em Arquivo no canto superior esquerdo e selecione salvar uma cópia na unidade
#
# **Suas alterações não serão salvas se você não fizer esta etapa**
#
# 2.) Clique no nome da pasta de trabalho no canto superior esquerdo e substitua "Cópia de" pelo seu nome completo
#
# **Você enviará o arquivo do notebook baixado como prova de conclusão deste módulo**

# %% [markdown]
# Por favor digite:
# ```
# print("Sim, fiz o passo 1")
# ```
# no bloco de código abaixo e, em seguida, execute clicando no ícone "triângulo"/"Play" nesse bloco

# %%
#Este bloco será verificado

# %% [markdown]
# Por favor digite:
# ```
# print("Sim, concluí o passo 2")
# ```
# no bloco de código abaixo e, em seguida, execute clicando no ícone "triângulo"/"Play" nesse bloco

# %% [markdown]
# ## Exercício
#
# Nesta tarefa, espera-se que você recupere arquivos FASTQ de um projeto de sequenciamento do genoma realizado em Hong Kong. O BioProject contendo essas leituras está depositado no ENA EBI: https://www.ebi.ac.uk/ena/browser/view/PRJNA627286
# Aqui está o que você deve fazer e documentar todas as suas etapas usando o notebook.
#
# 1. Existem cinco bioamostras no bioprojeto, use o comando wget para baixar todos os arquivos FASTQ (arquivos FASTQ individuais ONT)
# 2. Instale o condacolab
# 3. Instale o EPI2ME Artic Pipeline
# 4. Construa genomas de consenso a partir dos arquivos FASTQ usando EPI2ME
# 5. Identificar as linhagens nos isolados
# 6. Relate suas descobertas
